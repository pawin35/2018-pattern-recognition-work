# %% [markdown]
# # Two-Layer Neural Networks
#
# In this part of the homework, we will work on building a simple Neural Network to classify digits using MNIST dataset. There are many powerful neural network frameworks nowadays that are relatively straightforward to use. However, we believe that in order to understand the theory behind neural networks, and to have the right intuitions in order to build, use, and debug more complex architectures, one must first start from the basics.
#
# Your task is to complete the missing codes needed for training and testing of a simple fully-connected neural network.
#
# The missing parts will be marked with TODO#N, where N represents the task number.
#
# Many parts in this homework are modified from Stanford's cs231n assignments.

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

from cattern.neural_net import TwoLayerNet

# %load_ext autoreload
# %autoreload 2

# %%
# Just a function that verifies if your answers are correct

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cattern/neural_net.py` to represent instances of our network. The network parameters (weights and biases) are stored in the instance variable `self.params` where the keys are parameter names and values are numpy arrays. Below, we initialize some toy data and a toy model that will guide you with your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cattern/neural_net.py` and look at the method `TwoLayerNet.loss`. This function takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Complete TODO#1 in `TwoLayerNet.loss`, by implementing the first part of the forward pass which uses the weights and biases to compute the scores for all inputs. The scores refer to the output of the network just before the softmax layer.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720745909845e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, complete TODO#2 by implementing the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
print(loss, correct_loss)
# Out:
# Difference between your loss and correct loss:
# 1.794120407794253e-13
# 1.3037878913298206 1.30378789133

# %% [markdown]
# # Backward pass
# Implement the rest of the function by completing TODO#3. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cattern.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b1 max relative error: 2.738420e-09
# W2 max relative error: 3.440708e-09
# W1 max relative error: 4.090897e-09
# b2 max relative error: 3.865070e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD). Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure (TODO#4-6). You will also have to implement `TwoLayerNet.predict` (TODO#7), as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.05.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.015629050837161474

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up MNIST data so we can use it to train a classifier on a real dataset.

# %%
from mnist_data import load_mnist


def get_mnist_data(num_training=55000, num_validation=5000, num_test=10000):
    """
    Load the MNIST dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier.
    """
    # Load the raw MNIST data
    X_train, y_train, X_val, y_val, X_test, y_test = load_mnist.read_data_sets('mnist_data')

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train = X_train - mean_image
    X_val = X_val - mean_image
    X_test = X_test - mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_mnist_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Extracting mnist_data/train-images-idx3-ubyte.gz
# Extracting mnist_data/train-labels-idx1-ubyte.gz
# Extracting mnist_data/t10k-images-idx3-ubyte.gz
# Extracting mnist_data/t10k-labels-idx1-ubyte.gz
# Train data shape:  (55000, 784)
# Train labels shape:  (55000,)
# Validation data shape:  (5000, 784)
# Validation labels shape:  (5000,)
# Test data shape:  (10000, 784)
# Test labels shape:  (10000,)

# %%
from mnist_data.vis_utils import visualize_grid

# Visualize mnist data

def show_mnist_image(data):
  data = data.reshape(-1, 28, 28, 1)
  plt.imshow(visualize_grid(data, padding=3).astype('uint8').squeeze(axis=2))
  plt.gca().axis('off')
  plt.show()

show_mnist_image(X_train[:36])

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. We will use fixed learning rate to train this model.

# %%
input_size = 28 * 28 * 1
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=2000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=1,
            reg=0, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 2000: loss 2.302570
# iteration 100 / 2000: loss 2.302179
# iteration 200 / 2000: loss 2.300178
# iteration 300 / 2000: loss 2.288188
# iteration 400 / 2000: loss 2.206015
# iteration 500 / 2000: loss 1.934493
# iteration 600 / 2000: loss 1.786704
# iteration 700 / 2000: loss 1.302323
# iteration 800 / 2000: loss 1.171080
# iteration 900 / 2000: loss 1.008922
# iteration 1000 / 2000: loss 0.915802
# iteration 1100 / 2000: loss 0.818822
# iteration 1200 / 2000: loss 0.623073
# iteration 1300 / 2000: loss 0.610001
# iteration 1400 / 2000: loss 0.496753
# iteration 1500 / 2000: loss 0.476374
# iteration 1600 / 2000: loss 0.402148
# iteration 1700 / 2000: loss 0.364528
# iteration 1800 / 2000: loss 0.375504
# iteration 1900 / 2000: loss 0.471214
# Validation accuracy:  0.8988

# %% [markdown]
# # Learning Rate Decay
#
# In the previous run, we used the same learning rate during the whole training process. This fix-sized learning rate disregards the benefit of larger learning rate at the beginning of the training, and it might suffer from overshooting around the minima.
#
# Add learning rate decay to the train function, run the model again with larger starting learning rate and learning rate decay, then compare the losses.

# %%
net = TwoLayerNet(input_size, hidden_size, num_classes)
stats_LRDecay = net.train(X_train, y_train, X_val, y_val,
                    num_iters=2000, batch_size=200,
                    learning_rate=5e-4, learning_rate_decay=0.95,
                    reg=0, verbose=True)

# Predict on the validation set
val_acc_LRDecay = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc_LRDecay)
# Out:
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.140536
# iteration 200 / 2000: loss 0.879799
# iteration 300 / 2000: loss 0.526850
# iteration 400 / 2000: loss 0.332166
# iteration 500 / 2000: loss 0.275321
# iteration 600 / 2000: loss 0.404601
# iteration 700 / 2000: loss 0.306058
# iteration 800 / 2000: loss 0.233823
# iteration 900 / 2000: loss 0.326281
# iteration 1000 / 2000: loss 0.259536
# iteration 1100 / 2000: loss 0.224004
# iteration 1200 / 2000: loss 0.242642
# iteration 1300 / 2000: loss 0.162635
# iteration 1400 / 2000: loss 0.192712
# iteration 1500 / 2000: loss 0.213127
# iteration 1600 / 2000: loss 0.257310
# iteration 1700 / 2000: loss 0.196059
# iteration 1800 / 2000: loss 0.264173
# iteration 1900 / 2000: loss 0.212532
# Validation accuracy:  0.9434

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.94 on the validation set. This isn't very good for MNIST data which has reports of up to 0.99 accuracy.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.
#
# (You can think of the first layer weights as a projection W^TX. This is very similar to how we project our training data using PCA projection in our previous homework. Just like how we visualize the eigenfaces. We can also visualize the weights of the neural network in the same manner.)
#
# Below, we will also show you lossed between two models we trained above. Do you notice the difference between the two?

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'], label='with_fixed_LR')
plt.plot(stats_LRDecay['loss_history'], label='with_LR_decay')
plt.title('Loss history')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.plot(stats_LRDecay['train_acc_history'], label='train_LRDecay')
plt.plot(stats_LRDecay['val_acc_history'], label='val_LRDecay')
plt.title('Classification accuracy history')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(28, 28, 1, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8').squeeze(axis=2))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 97.4% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on MNIST as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
accs = []
params = []
hidden_sizes = list(range(20,100,5))
regs = [0, 1e-8, 5e-8, 1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4]
learning_rates = [1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3]
decays = np.linspace(0.9,1,11)
iters = [1500, 2000, 2500, 3000]
batch_sizes = list(range(150,325,25))
for hidden_size in hidden_sizes:
	for reg_val in regs:
		for learning_rate in learning_rates:
			for decay in decays:
				for num_iter in iters:
					for batch in batch_sizes:
						net = TwoLayerNet(input_size, hidden_size, num_classes)
						stats = net.train(X_train, y_train, X_val, y_val, num_iters=num_iter, batch_size=batch, learning_rate=learning_rate, learning_rate_decay=decay, reg=reg_val, verbose=False)
						val_acc = (net.predict(X_val) == y_val).mean()
						accs.append(val_acc)
						params.append([hidden_size, reg_val, learning_rate, decay, num_iter, batch])
						print("Using hidden sizes=",hidden_size, ", reg strength=",reg_val, ", learning rate=",learning_rate, ", decay=",decay, ", number of iteration=",num_iter, ", batch size=",batch, "| obtain accuracy=", val_acc)

print("Best model\n")
best_acc_arg = np.array(accs).argmax()
val_acc = accs[best_acc_arg]
hidden_size, reg_val, learning_rate, decay, num_iter, batch = params[best_acc_arg]
print("Using hidden sizes=",hidden_size, ", reg strength=",reg_val, ", learning rate=",learning_rate, ", decay=",decay, ", number of iteration=",num_iter, ", batch size=",batch, "| obtain accuracy=", val_acc)
best_net = None # store the best model into this 
best_net = TwoLayerNet(input_size, hidden_size, num_classes)
#################################################################################
# TODO#8: Tune hyperparameters using the validation set. Store your best trained#
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 5e-07 , decay= 0.9 , number of iteration= 1500 , batch size= 300 | obtain accuracy= 0.0874
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 5e-07 , decay= 0.9 , number of iteration= 2000 , batch size= 150 | obtain accuracy= 0.144
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 5e-07 , decay= 0.9 , number of iteration= 2000 , batch size= 175 | obtain accuracy= 0.1688
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 5e-07 , decay= 0.9 , number of iteration= 2000 , batch size= 200 | obtain accuracy= 0.1722
# ...
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2000 , batch size= 275 | obtain accuracy= 0.8624
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2000 , batch size= 300 | obtain accuracy= 0.884
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 150 | obtain accuracy= 0.8984
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 175 | obtain accuracy= 0.8996
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 200 | obtain accuracy= 0.8932
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 225 | obtain accuracy= 0.8964
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 250 | obtain accuracy= 0.8922
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 275 | obtain accuracy= 0.8982
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 2500 , batch size= 300 | obtain accuracy= 0.8996
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 150 | obtain accuracy= 0.905
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 175 | obtain accuracy= 0.9106
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 200 | obtain accuracy= 0.9014
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 225 | obtain accuracy= 0.9108
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 250 | obtain accuracy= 0.9012
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 275 | obtain accuracy= 0.9092
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.98 , number of iteration= 3000 , batch size= 300 | obtain accuracy= 0.9086
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 150 | obtain accuracy= 0.8612
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 175 | obtain accuracy= 0.8516
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 200 | obtain accuracy= 0.8632
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 225 | obtain accuracy= 0.854
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 250 | obtain accuracy= 0.8086
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 275 | obtain accuracy= 0.838
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 1500 , batch size= 300 | obtain accuracy= 0.8498
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 150 | obtain accuracy= 0.8792
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 175 | obtain accuracy= 0.8884
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 200 | obtain accuracy= 0.8932
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 225 | obtain accuracy= 0.8858
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 250 | obtain accuracy= 0.8738
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 275 | obtain accuracy= 0.8788
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2000 , batch size= 300 | obtain accuracy= 0.8808
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 150 | obtain accuracy= 0.902
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 175 | obtain accuracy= 0.8996
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 200 | obtain accuracy= 0.9044
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 225 | obtain accuracy= 0.9046
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 250 | obtain accuracy= 0.8932
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 275 | obtain accuracy= 0.9006
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 2500 , batch size= 300 | obtain accuracy= 0.8972
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 150 | obtain accuracy= 0.9118
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 175 | obtain accuracy= 0.9082
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 200 | obtain accuracy= 0.9094
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 225 | obtain accuracy= 0.9054
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 250 | obtain accuracy= 0.9074
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 275 | obtain accuracy= 0.9066
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 0.99 , number of iteration= 3000 , batch size= 300 | obtain accuracy= 0.9088
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 150 | obtain accuracy= 0.8538
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 175 | obtain accuracy= 0.8544
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 200 | obtain accuracy= 0.8468
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 225 | obtain accuracy= 0.8612
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 250 | obtain accuracy= 0.8544
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 275 | obtain accuracy= 0.846
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 1500 , batch size= 300 | obtain accuracy= 0.865
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 150 | obtain accuracy= 0.8828
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 175 | obtain accuracy= 0.8876
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 200 | obtain accuracy= 0.8914
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 225 | obtain accuracy= 0.887
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 250 | obtain accuracy= 0.8818
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 275 | obtain accuracy= 0.896
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2000 , batch size= 300 | obtain accuracy= 0.8926
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 150 | obtain accuracy= 0.8938
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 175 | obtain accuracy= 0.905
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 200 | obtain accuracy= 0.9028
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 225 | obtain accuracy= 0.9022
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 250 | obtain accuracy= 0.9028
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 275 | obtain accuracy= 0.8984
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 2500 , batch size= 300 | obtain accuracy= 0.9024
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 150 | obtain accuracy= 0.9118
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 175 | obtain accuracy= 0.9134
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 200 | obtain accuracy= 0.9084
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 225 | obtain accuracy= 0.9122
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 250 | obtain accuracy= 0.9118
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 275 | obtain accuracy= 0.9094
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0001 , decay= 1.0 , number of iteration= 3000 , batch size= 300 | obtain accuracy= 0.9112
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 150 | obtain accuracy= 0.9314
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 175 | obtain accuracy= 0.9336
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 200 | obtain accuracy= 0.9264
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 225 | obtain accuracy= 0.9312
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 250 | obtain accuracy= 0.9268
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 275 | obtain accuracy= 0.9278
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 1500 , batch size= 300 | obtain accuracy= 0.9316
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 150 | obtain accuracy= 0.937
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 175 | obtain accuracy= 0.9394
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 200 | obtain accuracy= 0.9334
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 225 | obtain accuracy= 0.9378
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 250 | obtain accuracy= 0.9294
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 275 | obtain accuracy= 0.9254
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2000 , batch size= 300 | obtain accuracy= 0.9348
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 150 | obtain accuracy= 0.9428
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 175 | obtain accuracy= 0.9422
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 200 | obtain accuracy= 0.9338
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 225 | obtain accuracy= 0.9412
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 250 | obtain accuracy= 0.9278
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 275 | obtain accuracy= 0.9314
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 2500 , batch size= 300 | obtain accuracy= 0.9446
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 3000 , batch size= 150 | obtain accuracy= 0.9442
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 3000 , batch size= 175 | obtain accuracy= 0.9454
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 3000 , batch size= 200 | obtain accuracy= 0.9352
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 3000 , batch size= 225 | obtain accuracy= 0.9516
# Using hidden sizes= 20 , reg strength= 0 , learning rate= 0.0005 , decay= 0.9 , number of iteration= 3000 , batch size= 250 | obtain accuracy= 0.938
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-36a6a3ef4240> in <module>
#      14                                         for batch in batch_sizes:
#      15                                                 net = TwoLayerNet(input_size, hidden_size, num_classes)
# ---> 16                                                 stats = net.train(X_train, y_train, X_val, y_val, num_iters=num_iter, batch_size=batch, learning_rate=learning_rate, learning_rate_decay=decay, reg=reg_val, verbose=False)
#      17                                                 val_acc = (net.predict(X_val) == y_val).mean()
#      18                                                 accs.append(val_acc)
#
# ~\pat_4\hw4\cattern\neural_net.py in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, verbose)
#     181       else:
#     182         rand_idx = np.random.choice(N, batch_size, replace=False)
# --> 183         X_batch = X[rand_idx]
#     184         y_batch = y[rand_idx]
#     185       #########################################################################
#
# KeyboardInterrupt:

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 96.3%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-26fd2799494b> in <module>
# ----> 1 test_acc = (best_net.predict(X_test) == y_test).mean()
#       2 print('Test accuracy: ', test_acc)
#
# NameError: name 'best_net' is not defined
